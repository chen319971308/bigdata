# %% [markdown]
# <a href="https://colab.research.google.com/github/chen319971308/bigdata/blob/master/%E3%80%8CAssessment6_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
library(SportsAnalytics)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
NBA1617<-fetch_NBAPlayerStatistics("16-17")

# %%
head(NBA1819)
# Out:
#   League Name         Team Position GamesPlayed TotalMinutesPlayed
# 1 NBA    Alex Abrines OKL  SG       31           588
# 2 NBA    Quincy Acy   PHO  SF       10           121
# 3 NBA    Jaylen Adams ATL  PG       34           425
# 4 NBA    Steven Adams OKL  C        80          2667
# 5 NBA    Bam Adebayo  MIA  C        82          1908
# 6 NBA    Deng Adel    CLE  SF       18           196
#   FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 1  56            157                 41         127             ⋯  17
# 2   4             18                  2          15             ⋯   1
# 3  38            110                 25          74             ⋯  13
# 4 481            809                  0           2             ⋯ 119
# 5 280            487                  3          15             ⋯  72
# 6  11             36                  6          23             ⋯   1
#   Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# ...

# %%
ggplot(NBA1617,aes(x=Team,y=TotalPoints))+geom_line() # X座標:各隊伍的名稱 Y座標:該隊伍獲的的總分
# Out:
# plot without title

# %%
ggplot(NBA1617,aes(x=Team,y=TotalPoints))+geom_boxplot() # X座標:各隊伍的名稱 Y座標:該隊伍獲的的總分
# Out:
# plot without title

# %%
qplot(ThreesAttempted,data=NBA1617,fill=Position) # 各個守備位置進行的三分球投籃次數
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(ThreesAttempted,ThreesMade,data=NBA1617,color=Position) #各個守備位置進行的三分球投籃次數以及投進的三分球得分
# Out:
# plot without title
